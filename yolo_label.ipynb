# %% [markdown]
# # Requird module installation

# %%
! pip install ultralytics

# %%
! pip install split-folders

# %% [markdown]
# # Training

# %%
import splitfolders
folder=r'C:\new_dataset2'
splitfolders.ratio(folder,output=r'C:\new_dataset2',seed=42,ratio=(.8,.2))
# Out:
# Copying files: 2014 files [00:02, 676.45 files/s]

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")

# %%
#Hyper parameter tuning
#from ray import tune
#result_grid = model.tune(data="data2.yml",epochs=10)

# %%
#result_grid

# %%
model.train(data="data2.yml",epochs=40,val=True,cache=True,imgsz=600)
# Out:
# New https://pypi.org/project/ultralytics/8.0.164 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.162  Python-3.10.2 torch-2.0.1+cpu CPU (Intel Core(TM) i5-10400 2.90GHz)
# ...

# %%
! yolo detect val data=data.yml model=C:\Users\guest1.OTLBLRDSK008\Desktop\Project\runs\detect\train3\weights\best.pt

# %% [markdown]
# Drawbounding box on images

# %%
import cv2
from PIL import Image
model1 = YOLO(r"best.pt")
# The function cv2.imread() is used to read an image.
res = model1(r'img4.jpg')  # results list
for r in res:
    a=len(r.boxes)
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
print(a)
# Out:
# image 1/1 C:\Users\guest1.OTLBLRDSK008\Desktop\Project\samples\img4.jpg: 480x608 3 cracks, 385.0ms
# Speed: 2.0ms preprocess, 385.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 608)
# 3

# %% [markdown]
# Detect cracks from sample video

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO(r"best.pt")

# Open the video file
video_path =r'img1-2_aQ4aXlEz.mp4'
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x608 1 crack, 276.3ms
# Speed: 2.0ms preprocess, 276.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 crack, 303.6ms
# Speed: 2.0ms preprocess, 303.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 crack, 295.2ms
# Speed: 1.0ms preprocess, 295.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 crack, 285.6ms
# Speed: 2.0ms preprocess, 285.6ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 crack, 280.6ms
# Speed: 2.0ms preprocess, 280.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 crack, 282.6ms
# Speed: 3.0ms preprocess, 282.6ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 crack, 291.3ms
# Speed: 2.0ms preprocess, 291.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 crack, 272.9ms
# ...
